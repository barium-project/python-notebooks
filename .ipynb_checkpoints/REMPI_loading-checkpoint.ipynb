# %% [markdown]
# Just some quick plots of early 413 nm REMPI loading

# %%
rcParams['axes.linewidth'] = 4
rcParams["figure.figsize"] = 15, 10
from scipy.optimize import curve_fit

f0 = 725.25789
freq = np.array([725.25689, 725.25739, 725.25789, 725.25839, 725.25889])- f0
counts_413 = [10,23,46,43,8]
counts_control = [6,14,0,7,0]

plot(freq*1e6, counts_413 , 's', markersize = 14, color = 'm', label ='413 nm ON')
plot(freq*1e6, counts_control , 's', markersize = 14, color = 'b', label ='413 nm OFF')
xlabel('Frequency (MHz)', fontsize = 46)
ylabel('Ions Loaded', fontsize = 46)
tick_params(labelsize = 44)
tick_params(width=5, length=10)
legend(fontsize = 30, loc = 'upper left')
#show()

savefig('413_REMPI.png', bbox_inches='tight', transparent = True)
